# %%
import os
import importlib
import polarization_model
importlib.invalidate_caches()

import os
os.chdir(r'C:\Users\sherv\OneDrive\Desktop\CSSSA\GitHub Versions\polarization_model_v2\polarization_model_v2-main')
# %run experiments/run_source_comparison.py
# Out:
# Metric                                Gov       News     Reddit
# ------------------------------------------------------------
# Mean Disposition                  -0.1255     0.1778     0.8473
# Max Disposition                    1.1733     1.4080     1.8429
# First Protest Tick                   None       1240       1166
# First PWI Tick                       None       1270       1165
# First Mob Tick                       None       1315       1170
# Protests per Month                 0.0000    12.1896     8.1941
# PWI per Month                      0.0000     8.7359    24.4470
# Mobs per Month                     0.0000     8.8036    29.2551
# Total Protest Events               0.0000   726.0000   292.0000
# Total PWI Events                   0.0000   603.0000  1852.0000
# Total Mob Events                   0.0000   488.0000 12505.0000
#
# Protest onset order:
#   REDDIT (tick 1166) -> NEWS (tick 1240)
#
# Riot onset order:
#   REDDIT (tick 1165) -> NEWS (tick 1270)
#
# ...
